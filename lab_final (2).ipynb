# %% [markdown]
# # Importance of libaries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
# %matplotlib inline
import  seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Mining/Final_project/data.csv")
df.head(10)
# Out:
#   type_school school_accreditation  gender         interest residence  \
# 0    Academic                    A    Male  Less Interested     Urban
# 1    Academic                    A    Male  Less Interested     Urban
# 2    Academic                    B  Female  Very Interested     Urban
# 3  Vocational                    B    Male  Very Interested     Rural
# 4    Academic                    A  Female  Very Interested     Urban
# 5  Vocational                    B  Female  Less Interested     Rural
# 6    Academic                    A    Male  Very Interested     Rural
# 7    Academic                    B    Male  Very Interested     Rural
# 8    Academic                    B  Female        Uncertain     Rural
# 9    Academic                    B  Female  Very Interested     Rural
#
#    parent_age  parent_salary  house_area  average_grades  \
# 0          56        6950000        83.0           84.09
# 1          57        4410000        76.8           86.91
# ...

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   type_school            1000 non-null   object
#  1   school_accreditation   1000 non-null   object
#  2   gender                 1000 non-null   object
#  3   interest               1000 non-null   object
#  4   residence              1000 non-null   object
#  5   parent_age             1000 non-null   int64
#  6   parent_salary          1000 non-null   int64
#  7   house_area             1000 non-null   float64
#  8   average_grades         1000 non-null   float64
#  9   parent_was_in_college  1000 non-null   bool
#  10  in_college             1000 non-null   bool
# dtypes: bool(2), float64(2), int64(2), object(5)
# memory usage: 72.4+ KB

# %%
#Missing Value Cheack
df.isnull().sum()
# Out:
# type_school              0
# school_accreditation     0
# gender                   0
# interest                 0
# residence                0
# parent_age               0
# parent_salary            0
# house_area               0
# average_grades           0
# parent_was_in_college    0
# in_college               0
# dtype: int64

# %%
df.describe()
# Out:
#         parent_age  parent_salary   house_area  average_grades
# count  1000.000000   1.000000e+03  1000.000000     1000.000000
# mean     52.208000   5.381570e+06    74.515300       86.097200
# std       3.500427   1.397546e+06    15.293346        3.378738
# min      40.000000   1.000000e+06    20.000000       75.000000
# 25%      50.000000   4.360000e+06    64.600000       83.737500
# 50%      52.000000   5.440000e+06    75.500000       85.575000
# 75%      54.000000   6.382500e+06    84.825000       88.262500
# max      65.000000   1.000000e+07   120.000000       98.000000

# %%
# For knowing Diffrent type of coloums value
df.type_school.value_counts()
# Out:
# Academic      609
# Vocational    391
# Name: type_school, dtype: int64

# %%
df.school_accreditation.value_counts()
# Out:
# B    519
# A    481
# Name: school_accreditation, dtype: int64

# %%
df.interest.value_counts()
# Out:
# Very Interested     324
# Uncertain           261
# Less Interested     229
# Quiet Interested    100
# Not Interested       86
# Name: interest, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
# Correlation Metrix
# A correlation metrix can help us quickly understand the correlations between each pair of variables.
plt.figure(figsize=(15,5))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# Histogram for distribution
df.hist(figsize=(15,10),grid=True)
# Out:
# array([[<Axes: title={'center': 'parent_age'}>,
#         <Axes: title={'center': 'parent_salary'}>],
#        [<Axes: title={'center': 'house_area'}>,
#         <Axes: title={'center': 'average_grades'}>]], dtype=object)

# %%
df.plot(kind='density', subplots=True, layout=(4,3), sharex=False,
                     sharey=False,fontsize=12, figsize=(20,10))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>]], dtype=object)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='residence',data=df,hue='in_college')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='residence', y='parent_salary' ,data=df, hue='in_college')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='interest', data=df, hue='in_college')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='type_school',data=df,hue='in_college')
# Out:
# <Axes: xlabel='type_school', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(x="average_grades", hue="in_college", data=df)
# Out:
# <Axes: xlabel='average_grades', ylabel='Density'>

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(x="parent_salary", hue="in_college", data=df)
# Out:
# <Axes: xlabel='parent_salary', ylabel='Density'>

# %% [markdown]
# # Modeling

# %%
df["type_school"]=df["type_school"].map({'Academic':0,'Vocational':1})
df["school_accreditation"]=df["school_accreditation"].map({'A':0,'B':1})
df["gender"]=df["gender"].map({'Male':0,'Female':1})
df["interest"]=df["interest"].map({'Very Interested':0,'Uncertain':1,'Less Interested':2,
                                   'Quiet Interested':3,'Not Interested':4})
df["residence"]=df["residence"].map({'Urban':0,'Rural':1})
df["parent_was_in_college"] = df["parent_was_in_college"].astype(int)
df["in_college"] = df["in_college"].astype(int)

# %%
df.head(5)
# Out:
#    type_school  school_accreditation  gender  interest  residence  parent_age  \
# 0            0                     0       0         2          0          56
# 1            0                     0       0         2          0          57
# 2            0                     1       1         0          0          50
# 3            1                     1       0         0          1          49
# 4            0                     0       1         0          0          57
#
#    parent_salary  house_area  average_grades  parent_was_in_college  \
# 0        6950000        83.0           84.09                      0
# 1        4410000        76.8           86.91                      0
# 2        6500000        80.6           87.43                      0
# 3        6600000        78.2           82.12                      1
# 4        5250000        75.1           86.79                      0
#
#    in_college
# 0           1
# 1           1
# 2           1
# 3           1
# ...

# %%
x=df.drop(['in_college'],axis=1)
y=df['in_college']

# %% [markdown]
# # Classification

# %%
#import evaluate metrics libaries
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
# for train data set
from sklearn.model_selection import train_test_split
# for scaling the data
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Scaling the dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
y_train.value_counts()
# Out:
# 0    340
# 1    330
# Name: in_college, dtype: int64

# %% [markdown]
# # Smote Dataset

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(sampling_strategy='minority',random_state=0)
xtrain,ytrain=sm.fit_resample(x_train,y_train)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
log_score=log.score(x_test,y_test)
log_score
# Out:
# 0.5151515151515151

# %%
y_pre_log=log.predict(x_test)

# %%
logaccuracy=accuracy_score(y_test,y_pre_log)
logaccuracy
# Out:
# 0.5151515151515151

# %%
print(confusion_matrix(y_test,y_pre_log))
logConfusion=confusion_matrix(y_test,y_pre_log)
display=ConfusionMatrixDisplay(confusion_matrix=logConfusion)
display.plot()
print("\nHere classification report for LogisticRegrssion:\n",classification_report(y_test,y_pre_log))
print()
# Out:
# [[  0 160]
#  [  0 170]]
#
# Here classification report for LogisticRegrssion:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       160
#            1       0.52      1.00      0.68       170
#
#     accuracy                           0.52       330
#    macro avg       0.26      0.50      0.34       330
# weighted avg       0.27      0.52      0.35       330

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(random_state=0)
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
tree_score=tree.score(x_test,y_test)
tree_score
# Out:
# 0.8212121212121212

# %%
y_pre_tree=tree.predict(x_test)

# %%
treeAccuracy=accuracy_score(y_test,y_pre_tree)
treeAccuracy
# Out:
# 0.8212121212121212

# %%
print(confusion_matrix(y_test,y_pre_tree))
treeConfusion=confusion_matrix(y_test,y_pre_tree)
display=ConfusionMatrixDisplay(confusion_matrix=treeConfusion)
display.plot()
print("\nHere classification report for DecisionTree:\n",classification_report(y_test,y_pre_tree))
print()
# Out:
# [[132  28]
#  [ 31 139]]
#
# Here classification report for DecisionTree:
#                precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82       160
#            1       0.83      0.82      0.82       170
#
#     accuracy                           0.82       330
#    macro avg       0.82      0.82      0.82       330
# weighted avg       0.82      0.82      0.82       330

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier(random_state=0)
forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
forest_score=forest.score(x_test,y_test)
forest_score
# Out:
# 0.8696969696969697

# %%
y_pre_forest=forest.predict(x_test)

# %%
forestAccuracy=accuracy_score(y_test,y_pre_forest)
forestAccuracy
# Out:
# 0.8696969696969697

# %%
print(confusion_matrix(y_test,y_pre_forest))
forestConfusion=confusion_matrix(y_test,y_pre_forest)
display=ConfusionMatrixDisplay(confusion_matrix=forestConfusion)
display.plot()
print("\nHere classification report for RandomForest:\n",classification_report(y_test,y_pre_forest))
print()
# Out:
# [[144  16]
#  [ 27 143]]
#
# Here classification report for RandomForest:
#                precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       160
#            1       0.90      0.84      0.87       170
#
#     accuracy                           0.87       330
#    macro avg       0.87      0.87      0.87       330
# weighted avg       0.87      0.87      0.87       330

# %% [markdown]
# # K-N neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier()
kn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
kn_score=kn.score(x_test,y_test)
kn_score
# Out:
# 0.6848484848484848

# %%
y_pre_kn=kn.predict(x_test)

# %%
knAccuracy=accuracy_score(y_test,y_pre_kn)
knAccuracy
# Out:
# 0.6848484848484848

# %%
print(confusion_matrix(y_test,y_pre_kn))
knConfusion=confusion_matrix(y_test,y_pre_kn)
display=ConfusionMatrixDisplay(confusion_matrix=knConfusion)
display.plot()
print("\nHere classification report for K-N neighbors:\n",classification_report(y_test,y_pre_kn))
print()
# Out:
# [[111  49]
#  [ 55 115]]
#
# Here classification report for K-N neighbors:
#                precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       160
#            1       0.70      0.68      0.69       170
#
#     accuracy                           0.68       330
#    macro avg       0.68      0.69      0.68       330
# weighted avg       0.69      0.68      0.68       330

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
sv.score=sv.score(x_test,y_test)
sv.score
# Out:
# 0.706060606060606

# %%
y_pre_svm=sv.predict(x_test)

# %%
svmAccuracy=accuracy_score(y_test,y_pre_svm)
svmAccuracy
# Out:
# 0.706060606060606

# %%
print(confusion_matrix(y_test,y_pre_svm))
print("\nHere classification report for SVM\n",classification_report(y_test,y_pre_svm))
svmConfusion=confusion_matrix(y_test,y_pre_svm)
display=ConfusionMatrixDisplay(confusion_matrix=svmConfusion)
display.plot()
# Out:
# [[114  46]
#  [ 51 119]]
#
# Here classification report for SVM
#                precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70       160
#            1       0.72      0.70      0.71       170
#
#     accuracy                           0.71       330
#    macro avg       0.71      0.71      0.71       330
# weighted avg       0.71      0.71      0.71       330
